# %%
import pandas as pd
import matplotlib.pyplot as plt

from db_queries import get_location_metadata

# %%
loc_df = get_location_metadata(location_set_id=111, location_set_version_id=655)
df = pd.read_csv('/ihme/homes/rmbarber/covid-19/testing_effect_2020_05_11.csv')
df['Date'] = pd.to_datetime(df['Date'])

# %%
for location_id in df.location_id.unique():
    location_name = loc_df.loc[loc_df['location_id'] == location_id, 'location_name'].item()

    plot_df = df.loc[df['location_id'] == location_id]

    plt.figure(figsize=(11, 8.5))
    plt.plot(plot_df['Date'], plot_df['Daily case rate'] * plot_df['population'])
    plt.plot(plot_df['Date'], plot_df['Adjusted daily case rate'] * plot_df['population'])
    plt.title(location_name)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-2d4a4c8b106f> in <module>
#       1 for location_id in df.location_id.unique():
# ----> 2     location_name = loc_df.loc[loc_df['location_id'] == location_id, 'location_name'].item()
#       3
#       4     plot_df = df.loc[df['location_id'] == location_id]
#       5
#
# /ihme/covid-19/miniconda/envs/covid-deaths-2020-05-10_12-08-48/lib/python3.6/site-packages/pandas/core/base.py in item(self)
#     650             # numpy returns ints instead of datetime64/timedelta64 objects,
#     651             #  which we need to wrap in Timestamp/Timedelta/Period regardless.
# --> 652             return self.values.item()
#     653
#     654         if len(self) == 1:
#
# ValueError: can only convert an array of size 1 to a Python scalar

# %%
plot_df.columns
# Out:
# Index(['location_id', 'Date', 'Days', 'population', 'Confirmed',
#        'Confirmed case rate', 'Hospitalizations', 'Hospitalization rate',
#        'ln(hospitalization rate)', 'Deaths', 'Death rate', 'ln(death rate)',
#        'Observed ln(confirmed case rate)', 'ln(confirmed case rate)',
#        'Testing rate', 'Daily testing rate', 'Daily case rate',
#        'Adjusted daily case rate'],
#       dtype='object')

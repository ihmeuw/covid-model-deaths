# %%
import pandas as pd
import matplotlib.pyplot as plt

from db_queries import get_location_metadata

import warnings
warnings.simplefilter('ignore')

# %%
ln_cumul_df = pd.read_csv(f'/ihme/covid-19/deaths/dev/2020_05_14_cfrmod_split/model_data_ln_cumul.csv')

# %%
ln_cumul_df
# Out:
#        location_id                                      location_name  \
# 0               13                                           Malaysia
# 1               13                                           Malaysia
# 2               13                                           Malaysia
# 3               13                                           Malaysia
# 4               13                                           Malaysia
# ...            ...                                                ...
# 12750        60887  Washington except for King, Snohomish, and Spo...
# 12751        60887  Washington except for King, Snohomish, and Spo...
# 12752        60887  Washington except for King, Snohomish, and Spo...
# 12753        60887  Washington except for King, Snohomish, and Spo...
# 12754        60887  Washington except for King, Snohomish, and Spo...
#
#              Date  Confirmed case rate  Testing rate  Death rate  \
# 0      2020-01-31         0.000000e+00  1.724106e-07         0.0
# 1      2020-02-01         0.000000e+00  3.448212e-07         0.0
# 2      2020-02-02         9.584235e-08  5.172319e-07         0.0
# 3      2020-02-03         1.277898e-07  7.758478e-07         0.0
# 4      2020-02-04         1.277898e-07  1.120669e-06         0.0
# ...           ...                  ...           ...         ...
# 12750  2020-05-17         1.908681e-03  3.225367e-02         NaN
# 12751  2020-05-18         1.931400e-03  3.296533e-02         NaN
# 12752  2020-05-19         2.006240e-03  3.367490e-02         NaN
# 12753  2020-05-20         2.035909e-03  3.438448e-02         NaN
# 12754  2020-05-21         2.048738e-03  3.509405e-02         NaN
#
#          population  intercept  Model death rate  Model confirmed case rate  \
# 0      3.130140e+07          1        -19.561759                 -19.561759
# 1      3.130140e+07          1        -19.561759                 -19.561759
# 2      3.130140e+07          1        -19.561759                 -16.160561
# 3      3.130140e+07          1        -19.561759                 -15.872879
# 4      3.130140e+07          1        -19.561759                 -15.872879
# ...             ...        ...               ...                        ...
# 12750  3.741327e+06          1               NaN                  -6.261343
# 12751  3.741327e+06          1               NaN                  -6.249510
# 12752  3.741327e+06          1               NaN                  -6.211493
# 12753  3.741327e+06          1               NaN                  -6.196813
# 12754  3.741327e+06          1               NaN                  -6.190531
#
#        Model testing rate  Predicted death rate  intercept coefficient  \
# 0              -15.573387          7.191609e-10               -5.68429
# 1              -14.880240          6.675430e-10               -5.68429
# 2              -14.474775          1.237129e-08               -5.68429
# 3              -14.069309          1.521736e-08               -5.68429
# 4              -13.701585          1.462779e-08               -5.68429
# ...                   ...                   ...                    ...
# 12750           -3.434123          7.261025e-05               -6.12345
# 12751           -3.412299          7.307926e-05               -6.12345
# 12752           -3.391002          7.460672e-05               -6.12345
# 12753           -3.370150          7.520504e-05               -6.12345
# 12754           -3.349724          7.546255e-05               -6.12345
#
#        Model confirmed case rate coefficient  Model testing rate coefficient
# 0                                   0.871193                       -0.107454
# 1                                   0.871193                       -0.107454
# 2                                   0.871193                       -0.107454
# 3                                   0.871193                       -0.107454
# 4                                   0.871193                       -0.107454
# ...                                      ...                             ...
# 12750                               0.544125                        0.000000
# 12751                               0.544125                        0.000000
# 12752                               0.544125                        0.000000
# 12753                               0.544125                        0.000000
# 12754                               0.544125                        0.000000
#
# [12755 rows x 15 columns]
